# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmay21csu266/CSl348/blob/main/Untitled12_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset = pd.read_csv(r'/House_Rent_Dataset.csv')
print(dataset)
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     18-05-2022    2  10000  1100  Ground out of 2   Super Area
# 1     13-05-2022    2  20000   800       1 out of 3   Super Area
# 2     16-05-2022    2  17000  1000       1 out of 3   Super Area
# 3     04-07-2022    2  10000   800       1 out of 2   Super Area
# 4     09-05-2022    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  18-05-2022    2  15000  1000       3 out of 5  Carpet Area
# 4742  15-05-2022    3  29000  2000       1 out of 4   Super Area
# 4743  10-07-2022    3  35000  1750       3 out of 5  Carpet Area
# 4744  06-07-2022    3  45000  1500     23 out of 34  Carpet Area
# 4745  04-05-2022    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4741              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner
#
# [4746 rows x 12 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


dataset = pd.read_csv(r'/House_Rent_Dataset.csv')


correlation_matrix = dataset.corr()


positive_corr = correlation_matrix[correlation_matrix > 0.5]
negative_corr = correlation_matrix[correlation_matrix < -0.5]
zero_corr = correlation_matrix[abs(correlation_matrix) < 0.1]


for col1 in positive_corr.columns:
    for col2 in positive_corr.index:
        if col1 != col2 and not np.isnan(positive_corr.loc[col2, col1]):
            plt.scatter(dataset[col1], dataset[col2], label=f"Corr: {positive_corr.loc[col2, col1]:.2f}")
            plt.xlabel(col1)
            plt.ylabel(col2)
            plt.legend()
            plt.title("Positive Correlation Scatter Plot")
            plt.show()


for col1 in negative_corr.columns:
    for col2 in negative_corr.index:
        if col1 != col2 and not np.isnan(negative_corr.loc[col2, col1]):
            plt.scatter(dataset[col1], dataset[col2], label=f"Corr: {negative_corr.loc[col2, col1]:.2f}", color='red')
            plt.xlabel(col1)
            plt.ylabel(col2)
            plt.legend()
            plt.title("Negative Correlation Scatter Plot")
            plt.show()

for col1 in zero_corr.columns:
    for col2 in zero_corr.index:
        if col1 != col2 and not np.isnan(zero_corr.loc[col2, col1]):
            plt.scatter(dataset[col1], dataset[col2], label="Zero Correlation", color='green')
            plt.xlabel(col1)
            plt.ylabel(col2)
            plt.legend()
            plt.title("Zero Correlation Scatter Plot")
            plt.show()


plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# <ipython-input-4-61960a8249f6>:10: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = dataset.corr()
